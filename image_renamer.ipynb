# %%
import os
import shutil
import pandas as pd

# === Prompt for each path separately ===
excel_path = input("Enter the full path to the Excel file: ").strip()
sheet_name = input("Enter the Excel sheet name (e.g. TV): ").strip()
source_dir = input("Enter the source folder path (where the original images are): ").strip()
destination_dir = input("Enter the destination folder path (where renamed images will be saved): ").strip()

# === Create destination folder if it doesn't exist ===
os.makedirs(destination_dir, exist_ok=True)

# === Load Excel file ===
df = pd.read_excel(excel_path, sheet_name=sheet_name)

# === Relevant columns ===
poster_col = 'Poster'       # Column G
filename_col = 'Filename'   # Column L
distributor_col = 'Distributor'  # Column F

# === Drop rows with missing values ===
df = df.dropna(subset=[poster_col, filename_col])

# === Track missing files ===
missing_files = []

# === Copy and rename images ===
for _, row in df.iterrows():
    original_name = row[poster_col].strip()
    new_name = row[filename_col].strip()
    distributor = row[distributor_col] if pd.notna(row[distributor_col]) else "Unknown"

    source_file = os.path.join(source_dir, original_name)
    destination_file = os.path.join(destination_dir, new_name)

    if os.path.exists(source_file):
        shutil.copy(source_file, destination_file)
        print(f"✅ Copied: {original_name} → {new_name}")
    else:
        print(f"❌ Not found: {original_name}")
        missing_files.append((original_name, new_name, distributor))

# === Final report ===
print("\n" + "="*60)
print("📋 FINAL REPORT")
print("="*60)

if missing_files:
    print(f"\n⚠️ {len(missing_files)} image(s) were NOT found:\n")
    # Organize by distributor
    missing_df = pd.DataFrame(missing_files, columns=['Original Name', 'Expected Filename', 'Distributor'])
    grouped = missing_df.groupby('Distributor')

    for distributor, group in grouped:
        print(f"\nDistributor: {distributor}")
        for _, row in group.iterrows():
            print(f"  - Missing: {row['Original Name']} → {row['Expected Filename']}")
else:
    print("🎉 All files were successfully found and copied!")

print("\nDone.")
#Z:\4_Metadata\Uganda Airlines - UR\2025\1025\Original images\Images tracker.xlsx
#TV
#Z:\4_Metadata\Uganda Airlines - UR\2025\1025\Original images\TV\Poster
#Z:\4_Metadata\Uganda Airlines - UR\2025\1025\RAVE\Images\TV
# Out:
# Enter the full path to the Excel file:  Z:\4_Metadata\Uganda Airlines - UR\2025\1025\Original images\Images tracker.xlsx
# Enter the Excel sheet name (e.g. TV):  TV
# Enter the source folder path (where the original images are):  Z:\4_Metadata\Uganda Airlines - UR\2025\1025\Original images\TV\Poster
# Enter the destination folder path (where renamed images will be saved):  Z:\4_Metadata\Uganda Airlines - UR\2025\1025\RAVE\Images\TV
# ✅ Copied: Celine Dio n- A Star is Born (1).jpg → UGD_1025_CelineDionASta_S01E01_Th_EngFra.jpg
# ✅ Copied: Islanders S01 EP01.jpg → UGD_1025_Islanders_S01E08_Th_EngFra.jpg
# ✅ Copied: Nina Simone, The Legend Poster.jpg → UGD_1025_NinaSimoneTheL_S01E01_Th_EngFra.jpg
# ✅ Copied: Incas, The New Story (1).jpg → UGD_1025_IncasTheNewSto_S01E01_Th_EngFra.jpg
# ✅ Copied: Between Heaven and Earth (1).png → UGD_1025_BetweenHeavena_S01E01_Th_EngFra.jpg
# ✅ Copied: Bob Hearts Abishola Poster.jpg → UGD_1025_BobHeartsAbish_S03E03_Th_Eng.jpg
# ✅ Copied: Bob Hearts Abishola Poster.jpg → UGD_1025_BobHeartsAbish_S03E04_Th_Eng.jpg
# ✅ Copied: Bob Hearts Abishola Poster.jpg → UGD_1025_BobHeartsAbish_S03E05_Th_Eng.jpg
# ✅ Copied: Bob Hearts Abishola Poster.jpg → UGD_1025_BobHeartsAbish_S03E06_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E01_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E02_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E03_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E04_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E05_Th_Eng.jpg
# ✅ Copied: Call me Kat S02.jpg → UGD_1025_CallMeKat_S02E06_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E01_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E02_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E03_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E04_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E05_Th_Eng.jpg
# ✅ Copied: Two and a Half Men S10 poster.JPEG → UGD_1025_TwoandaHalfMen_S10E06_Th_Eng.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E01_Th_EngSpl.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E02_Th_EngSpl.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E03_Th_EngSpl.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E04_Th_EngSpl.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E05_Th_EngSpl.jpg
# ✅ Copied: Brilliant Minds (1).jpg → UGD_1025_BrilliantMinds_S01E07_Th_Eng.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S04E02_Th_EngFra.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S05E04_Th_EngFra.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S05E05_Th_EngFra.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S05E06_Th_EngFra.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S05E07_Th_EngFra.jpg
# ✅ Copied: Major Crimes.jpg → UGD_1025_MajorCrimes_S05E08_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E01_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E02_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E03_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E04_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E05_Th_Eng.jpg
# ✅ Copied: The 100 S04.jpg → UGD_1025_The100_S04E06_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E01_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E02_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E03_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E04_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E05_Th_Eng.jpg
# ✅ Copied: Kung Fu Poster (1).jpg → UGD_1025_KungFu_S01E06_Th_Eng.jpg
# ✅ Copied: Teen Titans S01 (1).jpg → UGD_1025_TeenTitans_S01E01_Th_Eng.jpg
# ✅ Copied: Teen Titans S01 (1).jpg → UGD_1025_TeenTitans_S01E02_Th_Eng.jpg
# ✅ Copied: The Sylvester  Tweety Mysteries-S04-VERT.jpg → UGD_1025_TheSylvesterTw_S04E12_Th_Eng.jpg
# ✅ Copied: The Sylvester  Tweety Mysteries-S04-VERT.jpg → UGD_1025_TheSylvesterTw_S04E13_Th_Eng.jpg
# ✅ Copied: Teen Titans Go! S01 (1).jpg → UGD_1025_TeenTitansGo_S01E01_Th_Eng.jpg
# ✅ Copied: Tom & Jerry Kids Show (1).jpg → UGD_1025_TomJerryKidsSh_S03E01_Th_Eng.jpg
# ✅ Copied: Tom & Jerry Kids Show (1).jpg → UGD_1025_TomJerryKidsSh_S03E02_Th_Eng.jpg
# ✅ Copied: Tom & Jerry Kids Show (1).jpg → UGD_1025_TomJerryKidsSh_S03E03_Th_Eng.jpg
# ✅ Copied: Firehouse Tales S01 Poster.jpg → UGD_1025_FirehouseTales_S01E01_Th_Eng.jpg
# ✅ Copied: Firehouse Tales S01 Poster.jpg → UGD_1025_FirehouseTales_S01E02_Th_Eng.jpg
# ✅ Copied: Centurions Poster Vert (Edited).jpg → UGD_1025_Centurions_S01E01_Th_Eng.jpg
# ✅ Copied: Centurions Poster Vert (Edited).jpg → UGD_1025_Centurions_S01E02_Th_Eng.jpg
#
# ============================================================
# 📋 FINAL REPORT
# ============================================================
# 🎉 All files were successfully found and copied!
#
# Done.
